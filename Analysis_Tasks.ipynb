# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_excel(r"C:\Users\Dell\Desktop\Data Analyst\AirBNB VOIS Project\Project\Airbnb_Open_Data.xlsx")

# %%
data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 3              Clinton Hill  40.68514 -73.95976  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
# 102598      Upper West Side  40.76807 -73.98342  United States  ...
#
#        service fee  minimum nights number of reviews last review  \
# 0            193.0            10.0               9.0  2021-10-19
# 1             28.0            30.0              45.0  2022-05-21
# 2            124.0             3.0               0.0         NaT
# 3             74.0            30.0             270.0  2019-07-05
# 4             41.0            10.0               9.0  2018-11-19
# ...            ...             ...               ...         ...
# 102594       169.0             1.0               0.0         NaT
# 102595       167.0             1.0               1.0  2015-07-06
# 102596       198.0             3.0               0.0         NaT
# 102597       109.0             2.0               5.0  2015-10-11
# 102598       206.0             1.0               0.0         NaT
#
#         reviews per month  review rate number  calculated host listings count  \
# 0                    0.21                 4.0                             6.0
# 1                    0.38                 4.0                             2.0
# 2                     NaN                 5.0                             1.0
# 3                    4.64                 4.0                             1.0
# 4                    0.10                 3.0                             1.0
# ...                   ...                 ...                             ...
# 102594                NaN                 3.0                             1.0
# 102595               0.02                 2.0                             2.0
# 102596                NaN                 5.0                             1.0
# 102597               0.10                 3.0                             1.0
# 102598                NaN                 3.0                             1.0
#
#         availability 365                                        house_rules  \
# 0                  286.0  Clean up and treat the home the way you'd like...
# 1                  228.0  Pet friendly but please confirm with me if the...
# 2                  352.0  I encourage you to use my kitchen, cooking and...
# 3                  322.0                                                NaN
# 4                  289.0  Please no smoking in the house, porch or on th...
# ...                  ...                                                ...
# 102594             227.0  No Smoking No Parties or Events of any kind Pl...
# 102595             395.0  House rules: Guests agree to the following ter...
# 102596             342.0                                                NaN
# 102597             386.0                                                NaN
# 102598              69.0                                                NaN
#
#        license
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 102594     NaN
# 102595     NaN
# 102596     NaN
# 102597     NaN
# 102598     NaN
#
# [102599 rows x 26 columns]

# %%
data.head(2)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
# 1  1002102               Skylit Midtown Castle  52335172823
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
# 1              45.0  2022-05-21               0.38                 4.0
#
#    calculated host listings count  availability 365  \
# 0                             6.0             286.0
# 1                             2.0             228.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
#
# [2 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102329 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102191 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  float64
#  12  cancellation_policy             102523 non-null  object
#  13  room type                       102599 non-null  object
#  14  Construction year               102385 non-null  float64
#  15  price                           102352 non-null  float64
#  16  service fee                     102326 non-null  float64
#  17  minimum nights                  102190 non-null  float64
#  18  number of reviews               102416 non-null  float64
#  19  last review                     86706 non-null   datetime64[ns]
#  20  reviews per month               86720 non-null   float64
#  21  review rate number              102273 non-null  float64
#  22  calculated host listings count  102280 non-null  float64
#  23  availability 365                102151 non-null  float64
#  24  house_rules                     47756 non-null   object
#  25  license                         2 non-null       object
# dtypes: datetime64[ns](1), float64(12), int64(2), object(11)
# memory usage: 20.4+ MB

# %%
data.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
#
#        instant_bookable  Construction year          price    service fee  \
# count     102494.000000      102385.000000  102352.000000  102326.000000
# mean           0.497785        2012.487464     625.293536     125.026924
# min            0.000000        2003.000000      50.000000      10.000000
# 25%            0.000000        2007.000000     340.000000      68.000000
# 50%            0.000000        2012.000000     624.000000     125.000000
# 75%            1.000000        2017.000000     913.000000     183.000000
# max            1.000000        2022.000000    1200.000000     240.000000
# std            0.499998           5.765556     331.671614      66.325739
#
#        minimum nights  number of reviews                    last review  \
# count   102190.000000      102416.000000                          86706
# mean         8.135845          27.483743  2019-06-12 03:40:52.065601024
# min      -1223.000000           0.000000            2012-07-11 00:00:00
# 25%          2.000000           1.000000            2018-10-28 00:00:00
# 50%          3.000000           7.000000            2019-06-14 00:00:00
# 75%          5.000000          30.000000            2019-07-05 00:00:00
# max       5645.000000        1024.000000            2058-06-16 00:00:00
# std         30.553781          49.508954                            NaN
#
#        reviews per month  review rate number  calculated host listings count  \
# count       86720.000000       102273.000000                   102280.000000
# mean            1.374022            3.279106                        7.936605
# min             0.010000            1.000000                        1.000000
# 25%             0.220000            2.000000                        1.000000
# 50%             0.740000            3.000000                        1.000000
# 75%             2.000000            4.000000                        2.000000
# max            90.000000            5.000000                      332.000000
# std             1.746621            1.284657                       32.218780
#
#        availability 365
# count     102151.000000
# mean         141.133254
# min          -10.000000
# 25%            3.000000
# 50%           96.000000
# 75%          269.000000
# max         3677.000000
# std          135.435024

# %%
data[data.id.duplicated()]
# Out:
#               id                                              NAME  \
# 102058  35506831    Master Bedroom with private Bathroom & Balcony
# 102059  35507383                Cozy 2 br in sunny Fort Greene apt
# 102060  35507935               Duplex w/ Terrace @ Box House Hotel
# 102061  35508488      Cozy, clean Greenpoint room with yard access
# 102062  35509040  2BR XL Loft: Cleaning CDC guidelines implemented
# ...          ...                                               ...
# 102594   6092437                        Spare room in Williamsburg
# 102595   6092990                     Best Location near Columbia U
# 102596   6093542                    Comfy, bright room in Brooklyn
# 102597   6094094                  Big Studio-One Stop from Midtown
# 102598   6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified            host name  \
# 102058  55110690425            unconfirmed               UZeyir
# 102059  80193772189               verified                Sally
# 102060  72991962259               verified  The Box House Hotel
# 102061  74975156081               verified                 Dawn
# 102062  85844415221            unconfirmed                 Vida
# ...             ...                    ...                  ...
# 102594  12312296767               verified                 Krik
# 102595  77864383453            unconfirmed                Mifan
# 102596  69050334417            unconfirmed                Megan
# 102597  11160591270            unconfirmed          Christopher
# 102598  68170633372            unconfirmed              Rebecca
#
#        neighbourhood group        neighbourhood       lat      long  \
# 102058              Queens              Maspeth  40.74056 -73.90635
# 102059            Brooklyn          Fort Greene  40.68701 -73.97555
# 102060            Brooklyn           Greenpoint  40.73756 -73.95350
# 102061            Brooklyn           Greenpoint  40.72516 -73.95004
# 102062            Brooklyn           Greenpoint  40.72732 -73.94185
# ...                    ...                  ...       ...       ...
# 102594            Brooklyn         Williamsburg  40.70862 -73.94651
# 102595           Manhattan  Morningside Heights  40.80460 -73.96545
# 102596            Brooklyn           Park Slope  40.67505 -73.98045
# 102597              Queens     Long Island City  40.74989 -73.93777
# 102598           Manhattan      Upper West Side  40.76807 -73.98342
#
#               country  ... service fee  minimum nights number of reviews  \
# 102058  United States  ...       141.0             1.0               1.0
# 102059  United States  ...       130.0             3.0              38.0
# 102060  United States  ...       181.0             3.0              10.0
# 102061  United States  ...       118.0            30.0              38.0
# 102062  United States  ...        71.0            30.0              13.0
# ...               ...  ...         ...             ...               ...
# 102594  United States  ...       169.0             1.0               0.0
# 102595  United States  ...       167.0             1.0               1.0
# 102596  United States  ...       198.0             3.0               0.0
# 102597  United States  ...       109.0             2.0               5.0
# 102598  United States  ...       206.0             1.0               0.0
#
#        last review  reviews per month  review rate number  \
# 102058  2021-11-14               0.27                 3.0
# 102059  2021-11-13               0.27                 3.0
# 102060  2021-11-13               0.08                 3.0
# 102061  2021-11-13               0.34                 5.0
# 102062  2021-11-13               0.14                 4.0
# ...            ...                ...                 ...
# 102594         NaT                NaN                 3.0
# 102595  2015-07-06               0.02                 2.0
# 102596         NaT                NaN                 5.0
# 102597  2015-10-11               0.10                 3.0
# 102598         NaT                NaN                 3.0
#
#         calculated host listings count  availability 365  \
# 102058                             1.0             339.0
# 102059                             1.0               0.0
# 102060                            30.0              32.0
# 102061                             2.0             324.0
# 102062                            28.0             336.0
# ...                                ...               ...
# 102594                             1.0             227.0
# 102595                             2.0             395.0
# 102596                             1.0             342.0
# 102597                             1.0             386.0
# 102598                             1.0              69.0
#
#                                               house_rules license
# 102058                                                NaN     NaN
# 102059                                                NaN     NaN
# 102060                                                NaN     NaN
# 102061                                                NaN     NaN
# 102062                                                NaN     NaN
# ...                                                   ...     ...
# 102594  No Smoking No Parties or Events of any kind Pl...     NaN
# 102595  House rules: Guests agree to the following ter...     NaN
# 102596                                                NaN     NaN
# 102597                                                NaN     NaN
# 102598                                                NaN     NaN
#
# [541 rows x 26 columns]

# %%
data.drop_duplicates(inplace = True)

# %%
data.drop(['house_rules', 'license'], axis = 1, inplace = True)

# %%
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (83390, 26)

# %%
data.isnull().sum()
# Out:
# id                                0
# NAME                              0
# host id                           0
# host_identity_verified            0
# host name                         0
# neighbourhood group               0
# neighbourhood                     0
# lat                               0
# long                              0
# country                           0
# country code                      0
# instant_bookable                  0
# cancellation_policy               0
# room type                         0
# Construction year                 0
# price                             0
# service fee                       0
# minimum nights                    0
# number of reviews                 0
# last review                       0
# reviews per month                 0
# review rate number                0
# calculated host listings count    0
# availability 365                  0
# Month_Name                        0
# max_earning                       0
# dtype: int64

# %%
data.country.unique()
# Out:
# array(['United States'], dtype=object)

# %%
data.country.value_counts()
# Out:
# country
# United States    83390
# Name: count, dtype: int64

# %%
data['review rate number'].nunique()
# Out:
# 5

# %%
data['review rate number'].unique()
# Out:
# array([4., 3., 5., 2., 1.])

# %%
data.loc[data['review rate number'].idxmax()]
# Out:
# id                                            1005202
# NAME                                  BlissArtsSpace!
# host id                                   90821839709
# host_identity_verified                    unconfirmed
# host name                                        Emma
# neighbourhood group                          Brooklyn
# neighbourhood                      Bedford-Stuyvesant
# lat                                          40.68688
# long                                        -73.95596
# country                                 United States
# country code                                       US
# instant_bookable                                  0.0
# cancellation_policy                          moderate
# room type                                Private room
# Construction year                              2009.0
# price                                          1060.0
# service fee                                     212.0
# minimum nights                                   45.0
# number of reviews                                49.0
# last review                       2017-10-05 00:00:00
# reviews per month                                 0.4
# review rate number                                5.0
# calculated host listings count                    1.0
# availability 365                                219.0
# Month_Name                                    October
# max_earning                                   46428.0
# Name: 7, dtype: object

# %%
data.loc[data['review rate number'].idxmin()]
# Out:
# id                                                            1060984
# NAME                              Modern Brooklyn Apt., August sublet
# host id                                                   38981444696
# host_identity_verified                                    unconfirmed
# host name                                                         Ned
# neighbourhood group                                          Brooklyn
# neighbourhood                                            Williamsburg
# lat                                                          40.71459
# long                                                        -73.94844
# country                                                 United States
# country code                                                       US
# instant_bookable                                                  0.0
# cancellation_policy                                            strict
# room type                                             Entire home/apt
# Construction year                                              2017.0
# price                                                           589.0
# service fee                                                     118.0
# minimum nights                                                   30.0
# number of reviews                                                29.0
# last review                                       2018-05-26 00:00:00
# reviews per month                                                 0.4
# review rate number                                                1.0
# calculated host listings count                                    1.0
# availability 365                                                 83.0
# Month_Name                                                        May
# max_earning                                                    9794.0
# Name: 108, dtype: object

# %%
data.nlargest(10,'review rate number')
# Out:
#           id                                             NAME      host id  \
# 7    1005202                                  BlissArtsSpace!  90821839709
# 9    1006307               Cozy Clean Guest Room - Family Apt  75527839483
# 149  1083629                 Cozy BR in Wiliamsburg 3 Bedroom  26995415534
# 176  1098541              BROOKLYN VICTORIAN STYLE SUITE.....  83631499592
# 216  1120633                Cozy East Village Railroad 1 Bed!  79861348248
# 222  1123947               Great new apt, close to everything  79638424542
# 225  1125604               The Brownstone-Luxury 1 Bd Apt/NYC  95734990661
# 230  1128365                Nice, clean, safe, convenient 3BR  41153188173
# 231  1128917   Franklin St Flat in Trendy Greenpoint Brooklyn  25015494698
# 232  1129470  Artistic, Cozy, and Spacious w/ Patio! Sleeps 5  14920488865
#
#     host_identity_verified  host name neighbourhood group       neighbourhood  \
# 7              unconfirmed       Emma            Brooklyn  Bedford-Stuyvesant
# 9              unconfirmed       Carl           Manhattan     Upper West Side
# 149               verified      Bruce            Brooklyn        Williamsburg
# 176            unconfirmed  Frederick            Brooklyn         Fort Greene
# 216               verified     Cooper           Manhattan        East Village
# 222               verified       Ross           Manhattan      Hell's Kitchen
# 225               verified      Dixon           Manhattan              Harlem
# 230            unconfirmed     Fowler              Queens           Ridgewood
# 231            unconfirmed      Payne            Brooklyn          Greenpoint
# 232            unconfirmed      Adams           Manhattan           Chinatown
#
#           lat      long        country  ... service fee  minimum nights  \
# 7    40.68688 -73.95596  United States  ...       212.0            45.0
# 9    40.80178 -73.96723  United States  ...        58.0             2.0
# 149  40.71165 -73.96087  United States  ...       227.0             3.0
# 176  40.69098 -73.97113  United States  ...       231.0           -10.0
# 216  40.72752 -73.98432  United States  ...       218.0             1.0
# 222  40.76720 -73.98508  United States  ...       163.0             3.0
# 225  40.80931 -73.94343  United States  ...       165.0             3.0
# 230  40.70411 -73.89934  United States  ...       131.0            14.0
# 231  40.73401 -73.95967  United States  ...       102.0             2.0
# 232  40.71756 -73.99503  United States  ...       240.0             4.0
#
#     number of reviews last review  reviews per month  review rate number  \
# 7                49.0  2017-10-05               0.40                 5.0
# 9               118.0  2017-07-21               0.99                 5.0
# 149             200.0  2019-06-22               1.86                 5.0
# 176             213.0  2019-06-24               2.00                 5.0
# 216             204.0  2019-07-01               2.04                 5.0
# 222              94.0  2019-06-09               0.96                 5.0
# 225             222.0  2019-06-26               2.10                 5.0
# 230               1.0  2022-04-03               0.01                 5.0
# 231              69.0  2019-05-19               0.67                 5.0
# 232              18.0  2019-07-01               0.18                 5.0
#
#      calculated host listings count  availability 365  Month_Name max_earning
# 7                               1.0             219.0     October     46428.0
# 9                               1.0             375.0        July     21750.0
# 149                             4.0             166.0        June     37682.0
# 176                             2.0              19.0        June      4389.0
# 216                             1.0             353.0        July     76954.0
# 222                             1.0             395.0        June     64385.0
# 225                             2.0             188.0        June     31020.0
# 230                             5.0              80.0       April     10480.0
# 231                             1.0             146.0         May     14892.0
# 232                             2.0             382.0        July     91680.0
#
# [10 rows x 26 columns]

# %%
data[data['service fee'] == data['service fee'].max()]
# Out:
#               id                                               NAME  \
# 232      1129470    Artistic, Cozy, and Spacious w/ Patio! Sleeps 5
# 1141     1631510                 Perfect & Stylish Williamsburg Apt
# 1354     1749150                In_Manhattan+1 Small Block to train
# 1879     2039108                Charming Private room in Greenpoint
# 2589     2431241                  Beautiful Central Harlem sleeps 4
# ...          ...                                                ...
# 100042  56254533  Sun filled 1 bedroom in the heart of Crown Hei...
# 100430  56468825                   Lovely apartment in Williamsburg
# 101027  56798548               Harlem "Hostel" for Single Travelers
# 101437  57024991                              Charming Ground Floor
# 101881  57270212       BEST LOCATION IN SOHO AND SPACIOUS APARTMENT
#
#             host id host_identity_verified   host name neighbourhood group  \
# 232     14920488865            unconfirmed       Adams           Manhattan
# 1141    93573643506            unconfirmed        Jodi            Brooklyn
# 1354     1799553000            unconfirmed       Chris           Manhattan
# 1879    84297035315            unconfirmed          O.            Brooklyn
# 2589     6428506977               verified      London           Manhattan
# ...             ...                    ...         ...                 ...
# 100042  71957012044               verified       Linda            Brooklyn
# 100430  70301412872            unconfirmed       Harry            Brooklyn
# 101027  69989765859            unconfirmed  Sarah-Jane           Manhattan
# 101437  21118644141            unconfirmed         Joe              Queens
# 101881  83220442609            unconfirmed      Alonso           Manhattan
#
#         neighbourhood       lat      long        country  ... service fee  \
# 232         Chinatown  40.71756 -73.99503  United States  ...       240.0
# 1141     Williamsburg  40.70743 -73.96728  United States  ...       240.0
# 1354           Inwood  40.86284 -73.91955  United States  ...       240.0
# 1879       Greenpoint  40.73184 -73.95802  United States  ...       240.0
# 2589           Harlem  40.80861 -73.94574  United States  ...       240.0
# ...               ...       ...       ...            ...  ...         ...
# 100042  Crown Heights  40.67896 -73.95748  United States  ...       240.0
# 100430     Greenpoint  40.72253 -73.94350  United States  ...       240.0
# 101027         Harlem  40.81516 -73.94829  United States  ...       240.0
# 101437      Rego Park  40.72651 -73.86173  United States  ...       240.0
# 101881   Little Italy  40.71942 -73.99694  United States  ...       240.0
#
#         minimum nights number of reviews last review  reviews per month  \
# 232                4.0              18.0  2019-07-01               0.18
# 1141               7.0              69.0  2019-06-20               0.85
# 1354               4.0             142.0  2019-06-03               1.68
# 1879              11.0              11.0  2018-08-31               0.23
# 2589               3.0             123.0  2019-07-02               1.73
# ...                ...               ...         ...                ...
# 100042             4.0               3.0  2018-05-03               0.10
# 100430             7.0               6.0  2018-12-30               0.20
# 101027             2.0              36.0  2019-06-30               1.28
# 101437             1.0             101.0  2019-06-20               3.47
# 101881             1.0              67.0  2019-01-20               2.45
#
#         review rate number  calculated host listings count  availability 365  \
# 232                    5.0                             2.0             382.0
# 1141                   2.0                             1.0               1.0
# 1354                   4.0                             2.0             275.0
# 1879                   2.0                             3.0              -4.0
# 2589                   1.0                             3.0             266.0
# ...                    ...                             ...               ...
# 100042                 1.0                             1.0              13.0
# 100430                 2.0                             1.0              62.0
# 101027                 4.0                             2.0              88.0
# 101437                 4.0                             2.0              74.0
# 101881                 2.0                             1.0             189.0
#
#         Month_Name max_earning
# 232           July     91680.0
# 1141          June       240.0
# 1354          June     66000.0
# 1879        August      -960.0
# 2589          July     63840.0
# ...            ...         ...
# 100042         May      3120.0
# 100430    December     14880.0
# 101027        June     21120.0
# 101437        June     17760.0
# 101881     January     45360.0
#
# [212 rows x 26 columns]

# %%
data[data['service fee'] == data['service fee'].min()]
# Out:
#               id                                               NAME  \
# 360      1200164                  MANHATTAN Neat, Nice, Bright ROOM
# 364      1202373                   UWS Brownstone Near Central Park
# 905      1501168                Entire Apt: Sunny 2bd! 15min to NYC
# 959      1530992                Great apt on the UWS - A RARE FIND!
# 1006     1556950                  BROWNSTONE TWO IN BROOKLYN in NYC
# ...          ...                                                ...
# 97063   54609231                 Charming bedroom for female guests
# 98497   55401229  BP- BEAUTIFUL COZY  ROOM FOR 2 NEAR MANHATTAN ...
# 99395   55897195                          3rd Fl bright two bedroom
# 101331  56966447       3BR Home 25 Mins to Times Square + Manhattan
# 102008  57340354                Private Room in Brooklyn Brownstone
#
#             host id host_identity_verified host name neighbourhood group  \
# 360     81492867264               verified  Phillips           Manhattan
# 364     97440036171               verified     Grant           Manhattan
# 905     85566336401            unconfirmed     Owens            Brooklyn
# 959     17916840650            unconfirmed    Wilson           Manhattan
# 1006    54524181440               verified    Gibson            Brooklyn
# ...             ...                    ...       ...                 ...
# 97063   88464280209               verified  Stephany            Brooklyn
# 98497   84822579249            unconfirmed     Darry            Brooklyn
# 99395   96876814364               verified      Siyi            Brooklyn
# 101331  63029198256            unconfirmed  Nicholas              Queens
# 102008  57410631894            unconfirmed    Hallie            Brooklyn
#
#                     neighbourhood       lat      long        country  ...  \
# 360            Washington Heights  40.85295 -73.93361  United States  ...
# 364               Upper West Side  40.78558 -73.96960  United States  ...
# 905                 Crown Heights  40.66604 -73.95914  United States  ...
# 959               Upper West Side  40.78161 -73.97898  United States  ...
# 1006                     Bushwick  40.68979 -73.91661  United States  ...
# ...                           ...       ...       ...            ...  ...
# 97063   Prospect-Lefferts Gardens  40.66171 -73.94417  United States  ...
# 98497                Borough Park  40.64189 -73.99357  United States  ...
# 99395          Bedford-Stuyvesant  40.69295 -73.93875  United States  ...
# 101331                    Maspeth  40.73147 -73.89486  United States  ...
# 102008         Bedford-Stuyvesant  40.68119 -73.93722  United States  ...
#
#        service fee  minimum nights number of reviews last review  \
# 360           10.0             2.0             136.0  2019-06-17
# 364           10.0            21.0              45.0  2018-01-01
# 905           10.0             3.0              12.0  2019-07-07
# 959           10.0             3.0              22.0  2017-04-14
# 1006          10.0             3.0             112.0  2019-05-26
# ...            ...             ...               ...         ...
# 97063         10.0             1.0              85.0  2019-05-29
# 98497         10.0             5.0               5.0  2019-07-01
# 99395         10.0             1.0               4.0  2019-06-06
# 101331        10.0             1.0              60.0  2019-06-17
# 102008        10.0             2.0               2.0  2017-03-29
#
#         reviews per month  review rate number  calculated host listings count  \
# 360                  1.37                 4.0                             1.0
# 364                  0.46                 5.0                             1.0
# 905                  0.13                 5.0                             1.0
# 959                  0.25                 3.0                             1.0
# 1006                 1.28                 3.0                             8.0
# ...                   ...                 ...                             ...
# 97063                8.64                 4.0                             2.0
# 98497                0.53                 3.0                             8.0
# 99395                0.50                 3.0                             9.0
# 101331               3.05                 4.0                             1.0
# 102008               0.07                 2.0                             1.0
#
#         availability 365  Month_Name max_earning
# 360                312.0        June      3120.0
# 364                256.0     January      2560.0
# 905                 33.0        July       330.0
# 959                408.0       April      4080.0
# 1006               272.0         May      2720.0
# ...                  ...         ...         ...
# 97063                0.0         May         0.0
# 98497              364.0        July      3640.0
# 99395                7.0        June        70.0
# 101331             317.0        June      3170.0
# 102008               0.0       March         0.0
#
# [217 rows x 26 columns]

# %%
data[data.license == '41662/AL']

# %%
data[data['host_identity_verified'] == 'verified']

# %%
graph1 = data['host_identity_verified'].value_counts()

# %%
graph1

# %%
graph1.plot(kind = 'pie', startangle = 180, autopct ='%1.1f%%', shadow = True);
plt.title("No of Verified & Non-verified Hotels");
plt.savefig('Classified_Hotels.png', bbox_inches = 'tight', transparent = True)

# %%
data.head(2)

# %%
ver = data[data['host_identity_verified'] == 'verified']

# %%
ver.head(2)

# %%
graph2 = ver.groupby('NAME').agg({'service fee' : 'min', 'minimum nights' : 'max', 'review rate number' : 'max' , 'number of reviews' : 'max', 'availability 365' :'max'}).sort_values(by = ['service fee'], ascending = False)

# %%
graph2

# %%
graph2.hist(figsize = (10,8));
plt.savefig('Verified_Hotels_Hist.png',transparent = True, bbox_inches = 'tight' )

# %%
data.head(2)

# %%
data['host name'].nunique()

# %%
data['NAME'].nunique()

# %%
data['NAME'].value_counts()

# %%
ver.neighbourhood.nunique()
# Out:
# 223

# %%
ver['neighbourhood group'].nunique()
# Out:
# 7

# %%
ver.head(3)
# Out:
#         id                                              NAME      host id  \
# 1  1002102                             Skylit Midtown Castle  52335172823
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 1               verified     Jenna           Manhattan       Midtown
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long        country  ... service fee  minimum nights  \
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
# 4  40.79851 -73.94399  United States  ...        41.0            10.0
# 5  40.74767 -73.97500  United States  ...       115.0             3.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 1              45.0  2022-05-21               0.38                 4.0
# 4               9.0  2018-11-19               0.10                 3.0
# 5              74.0  2019-06-22               0.59                 3.0
#
#    calculated host listings count  availability 365  Month_Name max_earning
# 1                             2.0             228.0         May      6384.0
# 4                             1.0             289.0    November     11849.0
# 5                             1.0             374.0        June     43010.0
#
# [3 rows x 26 columns]

# %%
graph3 = ver.groupby('neighbourhood')[['service fee', 'review rate number']].mean().reset_index().head(10)

# %%
graph3.shape
# Out:
# (10, 3)

# %%
graph3
# Out:
#                 neighbourhood  service fee  review rate number
# 0                    Allerton   140.909091            3.465116
# 1               Arden Heights   172.500000            4.000000
# 2                    Arrochar   118.612903            3.600000
# 3                     Arverne   136.867769            3.239669
# 4                     Astoria   126.839873            3.194915
# 5                  Bath Beach   141.740741            3.392857
# 6           Battery Park City   121.982456            3.086207
# 7                   Bay Ridge   125.538462            3.131944
# 8                 Bay Terrace   135.285714            3.571429
# 9  Bay Terrace, Staten Island    12.000000            5.000000

# %%
figs, ax1 = plt.subplots(figsize = (15,8))
ax1.plot(graph3['neighbourhood'], graph3['service fee'], marker = 'o', label = 'service fee')
ax1.set_ylabel('Service fee', color ='blue')
ax1.set_xlabel('neighbourhood')

ax2 = ax1.twinx()
ax2.plot(graph3['neighbourhood'], graph3['review rate number'], color = 'cyan',marker = 'o', label = 'review rate number');
plt.xticks(rotation = 90)
ax2.set_ylabel('Review rate No' , color = 'blue')
plt.tight_layout()

lines, labels = ax1.get_legend_handles_labels()
lines1, lines1_labels = ax2.get_legend_handles_labels()
ax1.legend(lines + lines1, labels + lines1_labels, loc = 'upper left')

plt.show()
plt.savefig('Neghourhood_Verified.png', bbox_inches = 'tight')

# %%
ver.head(3)
# Out:
#         id                                              NAME      host id  \
# 1  1002102                             Skylit Midtown Castle  52335172823
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 1               verified     Jenna           Manhattan       Midtown
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long        country  ... service fee  minimum nights  \
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
# 4  40.79851 -73.94399  United States  ...        41.0            10.0
# 5  40.74767 -73.97500  United States  ...       115.0             3.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 1              45.0  2022-05-21               0.38                 4.0
# 4               9.0  2018-11-19               0.10                 3.0
# 5              74.0  2019-06-22               0.59                 3.0
#
#    calculated host listings count  availability 365  Month_Name max_earning
# 1                             2.0             228.0         May      6384.0
# 4                             1.0             289.0    November     11849.0
# 5                             1.0             374.0        June     43010.0
#
# [3 rows x 26 columns]

# %%
graph4 = ver.groupby('neighbourhood group')[['service fee', 'availability 365']].mean().reset_index()

# %%
graph4
# Out:
#   neighbourhood group  service fee  availability 365
# 0               Bronx   125.385496        175.543712
# 1            Brooklyn   124.940730        128.894118
# 2           Manhattan   124.332286        141.505806
# 3              Queens   125.405327        160.733588
# 4       Staten Island   123.876087        194.889371
# 5             brookln   116.000000         47.000000
# 6            manhatan          NaN        325.000000

# %%
figs, ax3 = plt.subplots(figsize = (10,6))

ax3.bar(graph4['neighbourhood group'], graph4['service fee'], color = 'black', label = 'service fee')
ax3.set_ylabel('Service fee' , color= 'black')
ax3.set_xlabel('Neighbourhood Group')

ax4 = ax3.twinx()
ax4.bar(graph4['neighbourhood group'], graph4['availability 365'], color = 'grey', label = 'availability 365');
ax4.set_ylabel('Availability 365', color ='grey')

bars, labels1 = ax3.get_legend_handles_labels()
bars1, lines_labels2 = ax4.get_legend_handles_labels()
ax3.legend(bars + bars1, labels1 + lines_labels2, loc = 'upper left');
plt.savefig('Neighbourhood_group_Verified.png', transparent = True, bbox_inches = 'tight');

# %%
data.head(1)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
#
#    calculated host listings count  availability 365  Month_Name max_earning
# 0                             6.0             286.0     October     55198.0
#
# [1 rows x 26 columns]

# %%
unver = data[data['host_identity_verified'] == 'unconfirmed']

# %%
unver
# Out:
#               id                                               NAME  \
# 0        1001254                 Clean & quiet apt home by the park
# 7        1005202                                    BlissArtsSpace!
# 9        1006307                 Cozy Clean Guest Room - Family Apt
# 41       1023980                                ENJOY Downtown NYC!
# 44       1025637                                  West Side Retreat
# ...          ...                                                ...
# 102019  57346430              Cozy private room in Brooklyn Heights
# 102021  57347534                                Mels Manhattan Home
# 102028  57351400  Gorgeous condo 20min from NYC,close to the air...
# 102029  57351953             Cozy room in a 2B with backyard access
# 102032  57353610                             Spacious Room w/ 2 Bed
#
#             host id host_identity_verified  host name neighbourhood group  \
# 0       80014485718            unconfirmed   Madaline            Brooklyn
# 7       90821839709            unconfirmed       Emma            Brooklyn
# 9       75527839483            unconfirmed       Carl           Manhattan
# 41      63131487263            unconfirmed      Byron           Manhattan
# 44      55430108992            unconfirmed     Alford           Manhattan
# ...             ...                    ...        ...                 ...
# 102019  66529113083            unconfirmed    Colette            Brooklyn
# 102021  56933792344            unconfirmed    Melissa           Manhattan
# 102028  27226581142            unconfirmed     Arthur              Queens
# 102029   5155155913            unconfirmed   Cristina              Queens
# 102032  69037598918            unconfirmed  Christine              Queens
#
#              neighbourhood       lat      long        country  ...  \
# 0               Kensington  40.64749 -73.97237  United States  ...
# 7       Bedford-Stuyvesant  40.68688 -73.95596  United States  ...
# 9          Upper West Side  40.80178 -73.96723  United States  ...
# 41            East Village  40.72290 -73.98199  United States  ...
# 44         Upper West Side  40.79009 -73.97927  United States  ...
# ...                    ...       ...       ...            ...  ...
# 102019         Cobble Hill  40.68934 -73.99438  United States  ...
# 102021             Chelsea  40.73756 -73.99111  United States  ...
# 102028           Rego Park  40.72999 -73.86043  United States  ...
# 102029             Astoria  40.76987 -73.92679  United States  ...
# 102032             Bayside  40.75047 -73.75349  United States  ...
#
#        service fee  minimum nights number of reviews last review  \
# 0            193.0            10.0               9.0  2021-10-19
# 7            212.0            45.0              49.0  2017-10-05
# 9             58.0             2.0             118.0  2017-07-21
# 41           113.0             2.0             245.0  2019-06-21
# 44           171.0             4.0              81.0  2019-06-16
# ...            ...             ...               ...         ...
# 102019       186.0             1.0               3.0  2017-03-27
# 102021       203.0             4.0               5.0  2017-12-30
# 102028       199.0             2.0              67.0  2019-07-01
# 102029       164.0             1.0               9.0  2019-04-25
# 102032        21.0             7.0              40.0  2019-06-23
#
#         reviews per month  review rate number  calculated host listings count  \
# 0                    0.21                 4.0                             6.0
# 7                    0.40                 5.0                             1.0
# 9                    0.99                 5.0                             1.0
# 41                   2.08                 3.0                             2.0
# 44                   0.69                 3.0                             1.0
# ...                   ...                 ...                             ...
# 102019               0.11                 2.0                             1.0
# 102021               0.18                 1.0                             1.0
# 102028               2.58                 5.0                             1.0
# 102029               0.91                 3.0                             1.0
# 102032               1.51                 1.0                             5.0
#
#         availability 365  Month_Name max_earning
# 0                  286.0     October     55198.0
# 7                  219.0     October     46428.0
# 9                  375.0        July     21750.0
# 41                 354.0        June     40002.0
# 44                  86.0        June     14706.0
# ...                  ...         ...         ...
# 102019               0.0       March         0.0
# 102021               0.0    December         0.0
# 102028             278.0        July     55322.0
# 102029               0.0       April         0.0
# 102032             148.0        June      3108.0
#
# [41705 rows x 26 columns]

# %%
unver['host name'].nunique()
# Out:
# 8907

# %%
graph5 = unver.groupby('NAME').agg({'service fee' : 'min', 'minimum nights' : 'max', 'review rate number' : 'max' , 'number of reviews' : 'max', 'availability 365' :'max'}).sort_values(by = ['service fee'], ascending = False)

# %%
graph5
# Out:
#                                                    service fee  \
# NAME
# An Urban Oasis in the Heart of Downtown Brooklyn         240.0
# Cozy room/creative space in modern bed stuy home.        240.0
# Perfect & Stylish Williamsburg Apt                       240.0
# Bushwick Room w/ Private Entrance & Bathroom!            240.0
# Main st APT w PRIVATE Bath, bedroom, living room.        240.0
# ...                                                        ...
# Vintage NYC apt - Monthly Rates!                          10.0
# Comfy 2BR + Outdoor patio/ Subway 2,3                     10.0
# twin bed in sharing room near Grand Central               10.0
# Close to NYC with No CLeaning Fees â€”-Q                  10.0
# Sonder | Stock Exchange | Cozy 1BR + Laundry              10.0
#
#                                                    minimum nights  \
# NAME
# An Urban Oasis in the Heart of Downtown Brooklyn              2.0
# Cozy room/creative space in modern bed stuy home.             1.0
# Perfect & Stylish Williamsburg Apt                            7.0
# Bushwick Room w/ Private Entrance & Bathroom!                 1.0
# Main st APT w PRIVATE Bath, bedroom, living room.             2.0
# ...                                                           ...
# Vintage NYC apt - Monthly Rates!                             30.0
# Comfy 2BR + Outdoor patio/ Subway 2,3                        28.0
# twin bed in sharing room near Grand Central                   6.0
# Close to NYC with No CLeaning Fees â€”-Q                      2.0
# Sonder | Stock Exchange | Cozy 1BR + Laundry                  2.0
#
#                                                    review rate number  \
# NAME
# An Urban Oasis in the Heart of Downtown Brooklyn                  5.0
# Cozy room/creative space in modern bed stuy home.                 4.0
# Perfect & Stylish Williamsburg Apt                                2.0
# Bushwick Room w/ Private Entrance & Bathroom!                     1.0
# Main st APT w PRIVATE Bath, bedroom, living room.                 3.0
# ...                                                               ...
# Vintage NYC apt - Monthly Rates!                                  5.0
# Comfy 2BR + Outdoor patio/ Subway 2,3                             5.0
# twin bed in sharing room near Grand Central                       4.0
# Close to NYC with No CLeaning Fees â€”-Q                          4.0
# Sonder | Stock Exchange | Cozy 1BR + Laundry                      4.0
#
#                                                    number of reviews  \
# NAME
# An Urban Oasis in the Heart of Downtown Brooklyn                10.0
# Cozy room/creative space in modern bed stuy home.               32.0
# Perfect & Stylish Williamsburg Apt                              69.0
# Bushwick Room w/ Private Entrance & Bathroom!                   16.0
# Main st APT w PRIVATE Bath, bedroom, living room.              157.0
# ...                                                              ...
# Vintage NYC apt - Monthly Rates!                                 7.0
# Comfy 2BR + Outdoor patio/ Subway 2,3                           12.0
# twin bed in sharing room near Grand Central                    174.0
# Close to NYC with No CLeaning Fees â€”-Q                       177.0
# Sonder | Stock Exchange | Cozy 1BR + Laundry                     6.0
#
#                                                    availability 365
# NAME
# An Urban Oasis in the Heart of Downtown Brooklyn               11.0
# Cozy room/creative space in modern bed stuy home.              36.0
# Perfect & Stylish Williamsburg Apt                            261.0
# Bushwick Room w/ Private Entrance & Bathroom!                  30.0
# Main st APT w PRIVATE Bath, bedroom, living room.              71.0
# ...                                                             ...
# Vintage NYC apt - Monthly Rates!                              365.0
# Comfy 2BR + Outdoor patio/ Subway 2,3                         183.0
# twin bed in sharing room near Grand Central                    45.0
# Close to NYC with No CLeaning Fees â€”-Q                      357.0
# Sonder | Stock Exchange | Cozy 1BR + Laundry                  327.0
#
# [32021 rows x 5 columns]

# %%
graph5.hist(figsize = (15, 8));

# %%
unver.head(2)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
# 7  1005202                     BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
# 7  40.68688 -73.95596  United States  ...       212.0            45.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
# 7              49.0  2017-10-05               0.40                 5.0
#
#    calculated host listings count  availability 365  Month_Name max_earning
# 0                             6.0             286.0     October     55198.0
# 7                             1.0             219.0     October     46428.0
#
# [2 rows x 26 columns]

# %%
graph6 = unver.groupby('neighbourhood')[['service fee', 'review rate number']].mean().reset_index().head(10)

# %%
graph6
# Out:
#                 neighbourhood  service fee  review rate number
# 0                    Allerton   122.093023            3.139535
# 1               Arden Heights   138.000000            3.333333
# 2                    Arrochar   131.526316            3.263158
# 3                     Arverne   121.250000            3.271739
# 4                     Astoria   129.700399            3.296937
# 5                  Bath Beach   168.125000            2.812500
# 6           Battery Park City   128.400000            3.100000
# 7                   Bay Ridge   119.838710            3.193548
# 8                 Bay Terrace    69.000000            4.000000
# 9  Bay Terrace, Staten Island   110.666667            3.000000

# %%
figs, g6 = plt.subplots(figsize = (15,6))

g6.plot(graph6['neighbourhood'], graph6['service fee'], marker = 'o', label = 'service fee', color = 'red')
g6.set_xlabel('NeighbourHood')
g6.set_ylabel('service fee', color = 'red')

g7 = g6.twinx()
g7.plot(graph6['neighbourhood'], graph6['review rate number'], marker = 'o', label = 'review rate number', color = 'yellow');
g7.set_ylabel('Review Rate No', color = 'Yellow')
plt.tight_layout();

plt.title('Unerified Hotes Fee & Reviews')
lines, labels = g6.get_legend_handles_labels()
lines1, lines_labels = g7.get_legend_handles_labels()
g6.legend(lines + lines1, labels + lines_labels, loc = 'upper left');
plt.savefig('Unverified Hotels fee & review.png', bbox_inches = 'tight')

# %%
graph7 = unver.groupby('neighbourhood group')[['service fee', 'availability 365']].mean().reset_index()

# %%
graph7
# Out:
#   neighbourhood group  service fee  availability 365
# 0               Bronx   125.768366        186.166811
# 1            Brooklyn   125.615531        133.029056
# 2           Manhattan   124.759417        139.320854
# 3              Queens   126.832703        168.036737
# 4       Staten Island   126.128571        204.707143

# %%
figs, g8 = plt.subplots()

g8.bar(graph7['neighbourhood group'], graph7['service fee'], color = 'cyan', label = 'service fee')
g8.set_xlabel('neighbourhood group')
g8.set_ylabel('service fee')

g9 = g8.twinx()
g9.plot(graph7['neighbourhood group'], graph7['availability 365'], color = 'plum',marker = 'o', label = 'availability 365');
g9.set_ylabel('Availability 365')
plt.tight_layout();

plt.title('Unverified Neighbouhood Groups Fee & Availability')
lines, labels = g8.get_legend_handles_labels()
lines2, lines_labels = g9.get_legend_handles_labels()
g8.legend(lines + lines2, labels + lines_labels, loc = 'upper left');

# %%
data.head(2)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
# 1  1002102               Skylit Midtown Castle  52335172823
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
# 1              45.0  2022-05-21               0.38                 4.0
#
#    calculated host listings count  availability 365  Month_Name max_earning
# 0                             6.0             286.0     October     55198.0
# 1                             2.0             228.0         May      6384.0
#
# [2 rows x 26 columns]

# %%
data['Month_Name'] = data['last review'].dt.month_name()

# %%
data
# Out:
#               id                                              NAME  \
# 0        1001254                Clean & quiet apt home by the park
# 1        1002102                             Skylit Midtown Castle
# 4        1003689  Entire Apt: Spacious Studio/Loft by central park
# 5        1004098         Large Cozy 1 BR Apartment In Midtown East
# 7        1005202                                   BlissArtsSpace!
# ...          ...                                               ...
# 102029  57351953            Cozy room in a 2B with backyard access
# 102030  57352505                      An East Williamsburg Delight
# 102031  57353057                      Cozy bedroom in williamsburg
# 102032  57353610                            Spacious Room w/ 2 Bed
# 102040  57358028                     Room in Queens, NY, near LGA.
#
#             host id host_identity_verified  host name neighbourhood group  \
# 0       80014485718            unconfirmed   Madaline            Brooklyn
# 1       52335172823               verified      Jenna           Manhattan
# 4       92037596077               verified     Lyndon           Manhattan
# 5       45498551794               verified   Michelle           Manhattan
# 7       90821839709            unconfirmed       Emma            Brooklyn
# ...             ...                    ...        ...                 ...
# 102029   5155155913            unconfirmed   Cristina              Queens
# 102030  71564706996               verified      Petra            Brooklyn
# 102031  83101851929               verified    Russell            Brooklyn
# 102032  69037598918            unconfirmed  Christine              Queens
# 102040  56457739998               verified      Sonia              Queens
#
#              neighbourhood       lat      long        country  ...  \
# 0               Kensington  40.64749 -73.97237  United States  ...
# 1                  Midtown  40.75362 -73.98377  United States  ...
# 4              East Harlem  40.79851 -73.94399  United States  ...
# 5              Murray Hill  40.74767 -73.97500  United States  ...
# 7       Bedford-Stuyvesant  40.68688 -73.95596  United States  ...
# ...                    ...       ...       ...            ...  ...
# 102029             Astoria  40.76987 -73.92679  United States  ...
# 102030  Bedford-Stuyvesant  40.68335 -73.91222  United States  ...
# 102031        Williamsburg  40.70870 -73.96710  United States  ...
# 102032             Bayside  40.75047 -73.75349  United States  ...
# 102040       East Elmhurst  40.76245 -73.87938  United States  ...
#
#        service fee  minimum nights number of reviews last review  \
# 0            193.0            10.0               9.0  2021-10-19
# 1             28.0            30.0              45.0  2022-05-21
# 4             41.0            10.0               9.0  2018-11-19
# 5            115.0             3.0              74.0  2019-06-22
# 7            212.0            45.0              49.0  2017-10-05
# ...            ...             ...               ...         ...
# 102029       164.0             1.0               9.0  2019-04-25
# 102030        91.0             4.0              36.0  2018-06-27
# 102031       216.0             1.0              58.0  2019-06-10
# 102032        21.0             7.0              40.0  2019-06-23
# 102040       196.0             1.0             239.0  2019-06-29
#
#         reviews per month  review rate number  calculated host listings count  \
# 0                    0.21                 4.0                             6.0
# 1                    0.38                 4.0                             2.0
# 4                    0.10                 3.0                             1.0
# 5                    0.59                 3.0                             1.0
# 7                    0.40                 5.0                             1.0
# ...                   ...                 ...                             ...
# 102029               0.91                 3.0                             1.0
# 102030               1.28                 1.0                             1.0
# 102031               2.08                 5.0                             2.0
# 102032               1.51                 1.0                             5.0
# 102040               8.58                 2.0                             2.0
#
#         availability 365  Month_Name max_earning
# 0                  286.0     October     55198.0
# 1                  228.0         May      6384.0
# 4                  289.0    November     11849.0
# 5                  374.0        June     43010.0
# 7                  219.0     October     46428.0
# ...                  ...         ...         ...
# 102029               0.0       April         0.0
# 102030               0.0        June         0.0
# 102031             120.0        June     25920.0
# 102032             148.0        June      3108.0
# 102040             361.0        June     70756.0
#
# [83390 rows x 26 columns]

# %%
data.head(2)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
# 1  1002102               Skylit Midtown Castle  52335172823
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
# 1              45.0  2022-05-21               0.38                 4.0
#
#    calculated host listings count  availability 365  Month_Name max_earning
# 0                             6.0             286.0     October     55198.0
# 1                             2.0             228.0         May      6384.0
#
# [2 rows x 26 columns]

# %%
data['max_earning'] = data['availability 365'] * data['service fee']

# %%
data
# Out:
#               id                                              NAME  \
# 0        1001254                Clean & quiet apt home by the park
# 1        1002102                             Skylit Midtown Castle
# 4        1003689  Entire Apt: Spacious Studio/Loft by central park
# 5        1004098         Large Cozy 1 BR Apartment In Midtown East
# 7        1005202                                   BlissArtsSpace!
# ...          ...                                               ...
# 102029  57351953            Cozy room in a 2B with backyard access
# 102030  57352505                      An East Williamsburg Delight
# 102031  57353057                      Cozy bedroom in williamsburg
# 102032  57353610                            Spacious Room w/ 2 Bed
# 102040  57358028                     Room in Queens, NY, near LGA.
#
#             host id host_identity_verified  host name neighbourhood group  \
# 0       80014485718            unconfirmed   Madaline            Brooklyn
# 1       52335172823               verified      Jenna           Manhattan
# 4       92037596077               verified     Lyndon           Manhattan
# 5       45498551794               verified   Michelle           Manhattan
# 7       90821839709            unconfirmed       Emma            Brooklyn
# ...             ...                    ...        ...                 ...
# 102029   5155155913            unconfirmed   Cristina              Queens
# 102030  71564706996               verified      Petra            Brooklyn
# 102031  83101851929               verified    Russell            Brooklyn
# 102032  69037598918            unconfirmed  Christine              Queens
# 102040  56457739998               verified      Sonia              Queens
#
#              neighbourhood       lat      long        country  ...  \
# 0               Kensington  40.64749 -73.97237  United States  ...
# 1                  Midtown  40.75362 -73.98377  United States  ...
# 4              East Harlem  40.79851 -73.94399  United States  ...
# 5              Murray Hill  40.74767 -73.97500  United States  ...
# 7       Bedford-Stuyvesant  40.68688 -73.95596  United States  ...
# ...                    ...       ...       ...            ...  ...
# 102029             Astoria  40.76987 -73.92679  United States  ...
# 102030  Bedford-Stuyvesant  40.68335 -73.91222  United States  ...
# 102031        Williamsburg  40.70870 -73.96710  United States  ...
# 102032             Bayside  40.75047 -73.75349  United States  ...
# 102040       East Elmhurst  40.76245 -73.87938  United States  ...
#
#        service fee  minimum nights number of reviews last review  \
# 0            193.0            10.0               9.0  2021-10-19
# 1             28.0            30.0              45.0  2022-05-21
# 4             41.0            10.0               9.0  2018-11-19
# 5            115.0             3.0              74.0  2019-06-22
# 7            212.0            45.0              49.0  2017-10-05
# ...            ...             ...               ...         ...
# 102029       164.0             1.0               9.0  2019-04-25
# 102030        91.0             4.0              36.0  2018-06-27
# 102031       216.0             1.0              58.0  2019-06-10
# 102032        21.0             7.0              40.0  2019-06-23
# 102040       196.0             1.0             239.0  2019-06-29
#
#         reviews per month  review rate number  calculated host listings count  \
# 0                    0.21                 4.0                             6.0
# 1                    0.38                 4.0                             2.0
# 4                    0.10                 3.0                             1.0
# 5                    0.59                 3.0                             1.0
# 7                    0.40                 5.0                             1.0
# ...                   ...                 ...                             ...
# 102029               0.91                 3.0                             1.0
# 102030               1.28                 1.0                             1.0
# 102031               2.08                 5.0                             2.0
# 102032               1.51                 1.0                             5.0
# 102040               8.58                 2.0                             2.0
#
#         availability 365  Month_Name max_earning
# 0                  286.0     October     55198.0
# 1                  228.0         May      6384.0
# 4                  289.0    November     11849.0
# 5                  374.0        June     43010.0
# 7                  219.0     October     46428.0
# ...                  ...         ...         ...
# 102029               0.0       April         0.0
# 102030               0.0        June         0.0
# 102031             120.0        June     25920.0
# 102032             148.0        June      3108.0
# 102040             361.0        June     70756.0
#
# [83390 rows x 26 columns]

# %%
data.head(3)
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
# 4  40.79851 -73.94399  United States  ...        41.0            10.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
# 1              45.0  2022-05-21               0.38                 4.0
# 4               9.0  2018-11-19               0.10                 3.0
#
#    calculated host listings count  availability 365  Month_Name max_earning
# 0                             6.0             286.0     October     55198.0
# 1                             2.0             228.0         May      6384.0
# 4                             1.0             289.0    November     11849.0
#
# [3 rows x 26 columns]

# %%
graph10 = data.groupby(['Month_Name','host name'])['max_earning'].max().sort_values(ascending = False).head(10)

# %%
graph10
# Out:
# Month_Name  host name
# June        Laura               871449.0
#             Ollie                99960.0
# May         Maria                99902.0
# July        Antonella            99303.0
#             Akiea                98514.0
# June        Warren & Jessica     98468.0
# November    Jen                  98280.0
# June        Jay                  98136.0
# July        Alexander            98046.0
# September   Nathaniel            97980.0
# Name: max_earning, dtype: float64

# %%
graph10 = graph10.unstack(level = 'Month_Name')

# %%
graph10
# Out:
# Month_Name            June      May     July  November  September
# host name
# Laura             871449.0      NaN      NaN       NaN        NaN
# Ollie              99960.0      NaN      NaN       NaN        NaN
# Maria                  NaN  99902.0      NaN       NaN        NaN
# Antonella              NaN      NaN  99303.0       NaN        NaN
# Akiea                  NaN      NaN  98514.0       NaN        NaN
# Warren & Jessica   98468.0      NaN      NaN       NaN        NaN
# Jen                    NaN      NaN      NaN   98280.0        NaN
# Jay                98136.0      NaN      NaN       NaN        NaN
# Alexander              NaN      NaN  98046.0       NaN        NaN
# Nathaniel              NaN      NaN      NaN       NaN    97980.0

# %%
graph10.plot(kind = 'barh', stacked = True, legend = True, grid = True);
plt.title('Estimate Monthly Earning of Hosts')
plt.xlabel('Monthly Total Earnings');
plt.savefig('Est_earning.png', bbox_inches = 'tight', transparent = True);

# %%
graph11 = data.groupby(['Month_Name','host name'])['max_earning'].min().sort_values(ascending = True).head(10)

# %%
graph11
# Out:
# Month_Name  host name
# June        Judy        -2370.0
# September   John        -2330.0
# May         Alexandra   -2230.0
# June        Chantal     -2150.0
# July        Dave        -2133.0
# December    Ryan        -2007.0
# April       Serafima    -1990.0
# June        Eva         -1960.0
#             Dixon       -1944.0
#             Peter       -1920.0
# Name: max_earning, dtype: float64

# %%
graph11 = graph11.unstack(level = 'Month_Name')

# %%
graph11
# Out:
# Month_Name    June  September     May    July  December   April
# host name
# Judy       -2370.0        NaN     NaN     NaN       NaN     NaN
# John           NaN    -2330.0     NaN     NaN       NaN     NaN
# Alexandra      NaN        NaN -2230.0     NaN       NaN     NaN
# Chantal    -2150.0        NaN     NaN     NaN       NaN     NaN
# Dave           NaN        NaN     NaN -2133.0       NaN     NaN
# Ryan           NaN        NaN     NaN     NaN   -2007.0     NaN
# Serafima       NaN        NaN     NaN     NaN       NaN -1990.0
# Eva        -1960.0        NaN     NaN     NaN       NaN     NaN
# Dixon      -1944.0        NaN     NaN     NaN       NaN     NaN
# Peter      -1920.0        NaN     NaN     NaN       NaN     NaN

# %%
graph11.plot(kind = 'bar', stacked = True, grid = True);
plt.title('Losses Of Hosts ')
plt.ylabel('Loss');
plt.savefig('Loss_Of host.png', transparent = True, bbox_inches ='tight');

# %%
data.head(2)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
# 1  1002102               Skylit Midtown Castle  52335172823
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
# 1              45.0  2022-05-21               0.38                 4.0
#
#    calculated host listings count  availability 365  Month_Name max_earning
# 0                             6.0             286.0     October     55198.0
# 1                             2.0             228.0         May      6384.0
#
# [2 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83390 entries, 0 to 102040
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              83390 non-null  int64
#  1   NAME                            83390 non-null  object
#  2   host id                         83390 non-null  int64
#  3   host_identity_verified          83390 non-null  object
#  4   host name                       83390 non-null  object
#  5   neighbourhood group             83390 non-null  object
#  6   neighbourhood                   83390 non-null  object
#  7   lat                             83390 non-null  float64
#  8   long                            83390 non-null  float64
#  9   country                         83390 non-null  object
#  10  country code                    83390 non-null  object
#  11  instant_bookable                83390 non-null  float64
#  12  cancellation_policy             83390 non-null  object
#  13  room type                       83390 non-null  object
#  14  Construction year               83390 non-null  float64
#  15  price                           83390 non-null  float64
#  16  service fee                     83390 non-null  float64
#  17  minimum nights                  83390 non-null  float64
#  18  number of reviews               83390 non-null  float64
#  19  last review                     83390 non-null  datetime64[ns]
#  20  reviews per month               83390 non-null  float64
#  21  review rate number              83390 non-null  float64
#  22  calculated host listings count  83390 non-null  float64
#  23  availability 365                83390 non-null  float64
#  24  Month_Name                      83390 non-null  object
#  25  max_earning                     83390 non-null  float64
# dtypes: datetime64[ns](1), float64(13), int64(2), object(10)
# memory usage: 19.2+ MB

# %%
data['id'] = data['id'].astype(str)
data['host id'] = data['host id'].astype(str)
data['Construction year'] = data['Construction year'].astype(int)

# %%
data.head(2)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
# 1  1002102               Skylit Midtown Castle  52335172823
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
# 1              45.0  2022-05-21               0.38                 4.0
#
#    calculated host listings count  availability 365  Month_Name max_earning
# 0                             6.0             286.0     October     55198.0
# 1                             2.0             228.0         May      6384.0
#
# [2 rows x 26 columns]

# %%
data.loc[data['neighbourhood group'] == 'brookln' , 'neighbourhood group'] = 'Brooklyn'

# %%
data = data.drop(data[data['availability 365'] > 500].index)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83389 entries, 0 to 102040
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              83389 non-null  object
#  1   NAME                            83389 non-null  object
#  2   host id                         83389 non-null  object
#  3   host_identity_verified          83389 non-null  object
#  4   host name                       83389 non-null  object
#  5   neighbourhood group             83389 non-null  object
#  6   neighbourhood                   83389 non-null  object
#  7   lat                             83389 non-null  float64
#  8   long                            83389 non-null  float64
#  9   country                         83389 non-null  object
#  10  country code                    83389 non-null  object
#  11  instant_bookable                83389 non-null  float64
#  12  cancellation_policy             83389 non-null  object
#  13  room type                       83389 non-null  object
#  14  Construction year               83389 non-null  int64
#  15  price                           83389 non-null  float64
#  16  service fee                     83389 non-null  float64
#  17  minimum nights                  83389 non-null  float64
#  18  number of reviews               83389 non-null  float64
#  19  last review                     83389 non-null  datetime64[ns]
#  20  reviews per month               83389 non-null  float64
#  21  review rate number              83389 non-null  float64
#  22  calculated host listings count  83389 non-null  float64
#  23  availability 365                83389 non-null  float64
#  24  Month_Name                      83389 non-null  object
#  25  max_earning                     83389 non-null  float64
# dtypes: datetime64[ns](1), float64(12), int64(1), object(12)
# memory usage: 17.2+ MB

# %%
data.duplicated().value_counts()
# Out:
# False    83389
# Name: count, dtype: int64

# %%
# What are the different property types in the dataset?
property_types = data['room type'].value_counts().to_frame()
property_types
# Out:
#                  count
# room type
# Entire home/apt  44161
# Private room     37474
# Shared room       1646
# Hotel room         108

# %%
plt.bar(property_types.index, property_types.loc[:,'count']);
plt.ylim([0, 50000])
plt.xlabel('Room Type')
plt.ylabel('Room Type Count')
plt.title('Property Types and their Count in the dataset');

# %%
# Which neighbourhood has the heigher number of listing?
hood_group = data['neighbourhood group'].value_counts().to_frame()
hood_group
# Out:
#                      count
# neighbourhood group
# Brooklyn             34622
# Manhattan            34560
# Queens               11124
# Bronx                 2267
# Staten Island          816

# %%
hood_group_bar = plt.bar(hood_group.index, hood_group.loc[:, 'count'])
plt.bar_label(hood_group_bar, labels = hood_group.loc[:,'count'], padding= 4);
plt.ylim(0,50000);
plt.xlabel('Neighbourhood Groups')
plt.ylabel('Nmber of Listings');

# %%
# Which neighbourhood group have the highest average prices for airbnb listings?
avg_price = data.groupby('neighbourhood group')['price'].mean().sort_values(ascending = False).to_frame()

# %%
avg_price
# Out:
#                           price
# neighbourhood group
# Queens               630.502517
# Bronx                630.201147
# Brooklyn             627.434261
# Manhattan            623.435561
# Staten Island        622.132353

# %%
avg_price_bar = plt.bar(avg_price.index, avg_price.loc[:, 'price']);
plt.ylim(0,700)
plt.bar_label(avg_price_bar, labels = round(avg_price.loc[:,'price'],2), label_type = 'edge', padding = 4)
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Price per Listings ($)')
plt.xticks(rotation = 45)
plt.title('Average price per listings ($) in eacg neighbourhood group');

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'Month_Name', 'max_earning'],
#       dtype='object')

# %%
# Is there a relatioship between the construction year of property and price?

data.groupby(data['Construction year'])['price'].mean().to_frame().plot()
plt.xlabel('Construciton Year')
plt.ylabel('Average Price in ($)')
plt.title('Average price ($) for properties in each constriction year');

# %%
hosts = data.groupby('host name')['calculated host listings count'].sum().sort_values(ascending = False).nlargest(10).to_frame()

# %%
hosts
# Out:
#                    calculated host listings count
# host name
# Sonder (NYC)                             111921.0
# Karen                                     42410.0
# Jeniffer                                  31447.0
# Blueground                                21168.0
# Kaz                                       17552.0
# Corporate Housing                         14833.0
# Soya                                      10260.0
# Stay With Vibe                            10260.0
# Kara                                      10092.0
# Jeremy & Laura                            10080.0

# %%
hosts_bar = plt.bar(hosts.index, hosts.loc[:,'calculated host listings count'])
plt.bar_label(hosts_bar, label = hosts.loc[:, 'calculated host listings count'], label_type = 'edge', padding =3);
plt.xlabel('Hosts Name')
plt.ylabel('Calculated hosts listings Count');
plt.xticks(rotation = 80)
plt.ylim([0,120000])
plt.title('Top 10 hosts by calculated host listings Count');

# %%
# Are Hosts with verified identities more likely to receive positive reviews?
review = data.groupby('host_identity_verified')['review rate number'].mean().sort_values(ascending = False).to_frame()

# %%
review
# Out:
#                         review rate number
# host_identity_verified
# verified                          3.284066
# unconfirmed                       3.273325

# %%
review_bar = plt.bar(review.index, review.loc[:,'review rate number'])
plt.bar_label(hosts_bar, labels = round(review.loc[:, 'review rate number'], 2),padding =3);
plt.xlabel('Host Verification Status')
plt.ylabel('Average Review rate number');
plt.ylim([0,4])
plt.title('Average review for each verification statistics');

# %%
# IS there a correration between the price of a listing and its service fee?
data['price'].corr(data['service fee'])
# Out:
# np.float64(0.9999909082976466)

# %%
sns.regplot(data, x= 'price', y = 'service fee');
plt.xlabel(' price in $')
plt.ylabel('Service fee in $')
plt.title('A regression plot showing the correlation of the price of a listing and its service fee');

# %%
# What is the avg review rate number for listing , and does it vary based on the neighbourhood group and room type?
avgrev = data.groupby(['neighbourhood group', 'room type'])['review rate number'].mean().to_frame()

# %%
avgrev
# Out:
#                                      review rate number
# neighbourhood group room type
# Bronx               Entire home/apt            3.381881
#                     Private room               3.305810
#                     Shared room                3.356322
# Brooklyn            Entire home/apt            3.242491
#                     Hotel room                 3.833333
#                     Private room               3.274773
#                     Shared room                3.323383
# Manhattan           Entire home/apt            3.268846
#                     Hotel room                 3.500000
#                     Private room               3.285431
#                     Shared room                3.261976
# Queens              Entire home/apt            3.349528
#                     Hotel room                 3.750000
#                     Private room               3.310847
#                     Shared room                3.327402
# Staten Island       Entire home/apt            3.333333
#                     Private room               3.497449
#                     Shared room                3.714286

# %%
plt.figure(figsize = (10,8))
sns.barplot( data =avgrev, x= 'neighbourhood group', y = 'review rate number', hue = 'room type')
plt.xlabel('Neighbourhood group')
plt.ylabel('Average review rate')
plt.title('Average Review for each Room/Property type in each Neighbourhood Group');
plt.savefig('barplot.png', transparent = True, bbox_inches = 'tight')

# %%
# Are hosts with the higher calculated host listings count more likely to maintian higher availability throughout the year?
sns.regplot(data,x = 'calculated host listings count', y = 'availability 365');
plt.xlabel('Calculated Host listing')
plt.ylabel('Availability 365')
plt.title('A regression Plot of the relationship between calculated host listing count and availability 365');
plt.savefig('regplot', bbox_inches = 'tight')

# %%
data['calculated host listings count'].corr(data['availability 365'])
# Out:
# np.float64(0.13599714715703387)
